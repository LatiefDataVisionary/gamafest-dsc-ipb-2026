# %% [markdown]
# <a href="https://colab.research.google.com/github/LatiefDataVisionary/gamafest-dsc-ipb-2026/blob/main/Copy_of_EDA_DF_Result_(Kunci_Jawaban).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df_result = pd.read_csv("https://raw.githubusercontent.com/LatiefDataVisionary/gamafest-dsc-ipb-2026/refs/heads/main/dataset/results.csv")
df_result.head(20)
# Out:
#           date         home_team away_team  home_score  away_score tournament  \
# 0   1872-11-30          Scotland   England         0.0         0.0   Friendly
# 1   1873-03-08           England  Scotland         4.0         2.0   Friendly
# 2   1874-03-07          Scotland   England         2.0         1.0   Friendly
# 3   1875-03-06           England  Scotland         2.0         2.0   Friendly
# 4   1876-03-04          Scotland   England         3.0         0.0   Friendly
# 5   1876-03-25          Scotland     Wales         4.0         0.0   Friendly
# 6   1877-03-03           England  Scotland         1.0         3.0   Friendly
# 7   1877-03-05             Wales  Scotland         0.0         2.0   Friendly
# 8   1878-03-02          Scotland   England         7.0         2.0   Friendly
# 9   1878-03-23          Scotland     Wales         9.0         0.0   Friendly
# 10  1879-01-18           England     Wales         2.0         1.0   Friendly
# ...

# %%
df_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49287 entries, 0 to 49286
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        49287 non-null  object
#  1   home_team   49287 non-null  object
#  2   away_team   49287 non-null  object
#  3   home_score  49215 non-null  float64
#  4   away_score  49215 non-null  float64
#  5   tournament  49287 non-null  object
#  6   city        49287 non-null  object
#  7   country     49287 non-null  object
#  8   neutral     49287 non-null  bool
# dtypes: bool(1), float64(2), object(6)
# memory usage: 3.1+ MB

# %%
df_result.describe()
# Out:
#          home_score    away_score
# count  49215.000000  49215.000000
# mean       1.756091      1.182404
# std        1.770617      1.401770
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      1.000000
# 75%        2.000000      2.000000
# max       31.000000     21.000000

# %% [markdown]
# # 📊 Professional Exploratory Data Analysis: International Football Results
#
# Analisis ini bertujuan untuk membedah dinamika sepak bola internasional dari tahun 1872 hingga sekarang. Kita akan mengeksplorasi tren gol, dominasi tim tuan rumah, dan evolusi kompetisi dunia.

# %% [markdown]
# ## Tahap 1: Data Cleaning & Advanced Feature Engineering
#
# Sebelum melakukan visualisasi, kita harus memastikan integritas data. Kita akan:
# 1. Menangani *missing values* pada skor.
# 2. Mengonversi tipe data kronologis.
# 3. Membuat fitur baru seperti `total_goals`, `goal_diff`, dan `match_outcome` untuk analisis yang lebih dalam.

# %%
# Out:
# /tmp/ipykernel_836/1547838160.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_result['date'] = pd.to_datetime(df_result['date'])
# /tmp/ipykernel_836/1547838160.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_result['year'] = df_result['date'].dt.year
# /tmp/ipykernel_836/1547838160.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# ## Tahap 2: Statistical Distribution Analysis
#
# Bagaimana distribusi gol dalam pertandingan internasional? Apakah ada anomali atau tren skor tinggi?

# %%
# Out:
# /tmp/ipykernel_836/2937799114.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=outcome_counts.index, y=outcome_counts.values, ax=ax[1], palette='viridis')

# %% [markdown]
# ## Tahap 3: Chronological Trends (Evolusi Sepak Bola)
#
# Mari kita analisis bagaimana produktivitas gol berubah dari abad ke-19 hingga era modern.

# %% [markdown]
# ## Tahap 4: Global Dominance & Team Performance Analysis
#
# Siapakah tim paling mematikan dalam sejarah? Kita akan menghitung statistik kumulatif untuk menemukan negara dengan performa paling konsisten.

# %% [markdown]
# ## Tahap 5: Tournament Segmentation
#
# Apakah laga persahabatan masih mendominasi, ataukah turnamen resmi telah mengambil alih panggung internasional?

# %% [markdown]
# ## Tahap 6: Seasonality & Neutral Venue Analysis
#
# Apakah periode musim kompetisi memengaruhi produktivitas gol? Dan apakah bermain di tempat netral benar-benar menghilangkan keuntungan statistik tim tuan rumah?

# %% [markdown]
# ## Tahap 7: Historical Anomalies & High-Scoring Records
#
# Terakhir, kita akan membedah 'outliers'—pertandingan dengan jumlah gol paling ekstrem yang pernah tercatat dalam sejarah sepak bola internasional.

# %%
# Out:
# 10 Pertandingan dengan Skor Tertinggi dalam Sejarah:
#             date   home_team       away_team  home_score  away_score  \
# 25420 2001-04-11   Australia  American Samoa        31.0         0.0
# 8547  1971-09-13      Tahiti    Cook Islands        30.0         0.0
# 11912 1979-08-30        Fiji        Kiribati        24.0         0.0
# 30513 2006-11-24       Sápmi          Monaco        21.0         1.0
# 25417 2001-04-09   Australia           Tonga        22.0         0.0
# 29040 2005-03-11        Guam     North Korea         0.0        21.0
# 21953 1997-05-13  Kazakhstan            Guam        20.0         1.0
# 6576  1966-04-03       Libya            Oman        21.0         0.0
# 37758 2014-06-01      Darfur         Padania         0.0        20.0
# 24177 2000-02-14      Kuwait          Bhutan        20.0         0.0
#
#                          tournament  total_goals
# 25420  FIFA World Cup qualification         31.0
# 8547            South Pacific Games         30.0
# ...

# %% [markdown]
# ## Tahap 6: Seasonality & Neutral Venue Analysis
#
# Apakah periode musim kompetisi memengaruhi produktivitas gol? Dan apakah bermain di tempat netral benar-benar menghilangkan keuntungan statistik tim tuan rumah?

# %% [markdown]
# ## Tahap 7: Historical Anomalies & High-Scoring Records
#
# Terakhir, kita akan membedah 'outliers'—pertandingan dengan jumlah gol paling ekstrem yang pernah tercatat dalam sejarah sepak bola internasional.

# %%
# Out:
# 10 Pertandingan dengan Skor Tertinggi dalam Sejarah:
#             date   home_team       away_team  home_score  away_score  \
# 25420 2001-04-11   Australia  American Samoa        31.0         0.0
# 8547  1971-09-13      Tahiti    Cook Islands        30.0         0.0
# 11912 1979-08-30        Fiji        Kiribati        24.0         0.0
# 30513 2006-11-24       Sápmi          Monaco        21.0         1.0
# 25417 2001-04-09   Australia           Tonga        22.0         0.0
# 29040 2005-03-11        Guam     North Korea         0.0        21.0
# 21953 1997-05-13  Kazakhstan            Guam        20.0         1.0
# 6576  1966-04-03       Libya            Oman        21.0         0.0
# 37758 2014-06-01      Darfur         Padania         0.0        20.0
# 24177 2000-02-14      Kuwait          Bhutan        20.0         0.0
#
#                          tournament  total_goals
# 25420  FIFA World Cup qualification         31.0
# 8547            South Pacific Games         30.0
# ...

# %% [markdown]
# ## Tahap 6: Seasonality & Neutral Venue Analysis
#
# Apakah periode musim kompetisi memengaruhi produktivitas gol? Dan apakah bermain di tempat netral benar-benar menghilangkan keuntungan statistik tim tuan rumah?

# %% [markdown]
# ## Tahap 7: Historical Anomalies & High-Scoring Records
#
# Terakhir, kita akan membedah 'outliers'—pertandingan dengan jumlah gol paling ekstrem yang pernah tercatat dalam sejarah sepak bola internasional.

# %%
# Out:
# 10 Pertandingan dengan Skor Tertinggi dalam Sejarah:
#             date   home_team       away_team  home_score  away_score  \
# 25420 2001-04-11   Australia  American Samoa        31.0         0.0
# 8547  1971-09-13      Tahiti    Cook Islands        30.0         0.0
# 11912 1979-08-30        Fiji        Kiribati        24.0         0.0
# 30513 2006-11-24       Sápmi          Monaco        21.0         1.0
# 25417 2001-04-09   Australia           Tonga        22.0         0.0
# 29040 2005-03-11        Guam     North Korea         0.0        21.0
# 21953 1997-05-13  Kazakhstan            Guam        20.0         1.0
# 6576  1966-04-03       Libya            Oman        21.0         0.0
# 37758 2014-06-01      Darfur         Padania         0.0        20.0
# 24177 2000-02-14      Kuwait          Bhutan        20.0         0.0
#
#                          tournament  total_goals
# 25420  FIFA World Cup qualification         31.0
# 8547            South Pacific Games         30.0
# ...

# %% [markdown]
# ## Tahap 6: Seasonality & Neutral Venue Analysis
#
# Apakah periode musim kompetisi memengaruhi produktivitas gol? Dan apakah bermain di tempat netral benar-benar menghilangkan keuntungan statistik tim tuan rumah?

# %% [markdown]
# ## Tahap 7: Historical Anomalies & High-Scoring Records
#
# Terakhir, kita akan membedah 'outliers'—pertandingan dengan jumlah gol paling ekstrem yang pernah tercatat dalam sejarah sepak bola internasional.

# %%
# Out:
# 10 Pertandingan dengan Skor Tertinggi dalam Sejarah:
#             date   home_team       away_team  home_score  away_score  \
# 25420 2001-04-11   Australia  American Samoa        31.0         0.0
# 8547  1971-09-13      Tahiti    Cook Islands        30.0         0.0
# 11912 1979-08-30        Fiji        Kiribati        24.0         0.0
# 30513 2006-11-24       Sápmi          Monaco        21.0         1.0
# 25417 2001-04-09   Australia           Tonga        22.0         0.0
# 29040 2005-03-11        Guam     North Korea         0.0        21.0
# 21953 1997-05-13  Kazakhstan            Guam        20.0         1.0
# 6576  1966-04-03       Libya            Oman        21.0         0.0
# 37758 2014-06-01      Darfur         Padania         0.0        20.0
# 24177 2000-02-14      Kuwait          Bhutan        20.0         0.0
#
#                          tournament  total_goals
# 25420  FIFA World Cup qualification         31.0
# 8547            South Pacific Games         30.0
# ...

# %% [markdown]
# ## Tahap 6: Seasonality & Neutral Venue Analysis
#
# Apakah cuaca atau periode musim kompetisi memengaruhi jumlah gol? Dan apakah bermain di tempat netral benar-benar menghilangkan keuntungan tuan rumah?

# %% [markdown]
# ## Tahap 7: High-Scoring Anomalies & Records
#
# Terakhir, kita akan melihat pertandingan dengan skor paling ekstrem untuk melihat 'outliers' dalam sejarah sepak bola.

# %%
# Out:
# 10 Pertandingan dengan Skor Tertinggi dalam Sejarah:
#             date   home_team       away_team  home_score  away_score  \
# 25420 2001-04-11   Australia  American Samoa        31.0         0.0
# 8547  1971-09-13      Tahiti    Cook Islands        30.0         0.0
# 11912 1979-08-30        Fiji        Kiribati        24.0         0.0
# 30513 2006-11-24       Sápmi          Monaco        21.0         1.0
# 25417 2001-04-09   Australia           Tonga        22.0         0.0
# 29040 2005-03-11        Guam     North Korea         0.0        21.0
# 21953 1997-05-13  Kazakhstan            Guam        20.0         1.0
# 6576  1966-04-03       Libya            Oman        21.0         0.0
# 37758 2014-06-01      Darfur         Padania         0.0        20.0
# 24177 2000-02-14      Kuwait          Bhutan        20.0         0.0
#
#                          tournament  total_goals
# 25420  FIFA World Cup qualification         31.0
# 8547            South Pacific Games         30.0
# ...

# %% [markdown]
# ## Tahap 6: Seasonality & Neutral Venue Analysis
#
# Apakah cuaca atau periode musim kompetisi memengaruhi jumlah gol? Dan apakah bermain di tempat netral benar-benar menghilangkan keuntungan tuan rumah?

# %% [markdown]
# ## Tahap 7: High-Scoring Anomalies & Records
#
# Terakhir, kita akan melihat pertandingan dengan skor paling ekstrem untuk melihat 'outliers' dalam sejarah sepak bola.

# %%
# Out:
# 10 Pertandingan dengan Skor Tertinggi dalam Sejarah:
#             date   home_team       away_team  home_score  away_score  \
# 25420 2001-04-11   Australia  American Samoa        31.0         0.0
# 8547  1971-09-13      Tahiti    Cook Islands        30.0         0.0
# 11912 1979-08-30        Fiji        Kiribati        24.0         0.0
# 30513 2006-11-24       Sápmi          Monaco        21.0         1.0
# 25417 2001-04-09   Australia           Tonga        22.0         0.0
# 29040 2005-03-11        Guam     North Korea         0.0        21.0
# 21953 1997-05-13  Kazakhstan            Guam        20.0         1.0
# 6576  1966-04-03       Libya            Oman        21.0         0.0
# 37758 2014-06-01      Darfur         Padania         0.0        20.0
# 24177 2000-02-14      Kuwait          Bhutan        20.0         0.0
#
#                          tournament  total_goals
# 25420  FIFA World Cup qualification         31.0
# 8547            South Pacific Games         30.0
# ...

# %% [markdown]
# ## Tahap 4: Global Dominance & Team Performance Analysis
#
# Siapakah tim paling mematikan dalam sejarah? Kita akan menghitung statistik kumulatif untuk menemukan negara dengan performa paling konsisten.

# %% [markdown]
# ## Tahap 5: Tournament Segmentation
#
# Apakah laga persahabatan masih mendominasi, ataukah turnamen resmi telah mengambil alih panggung internasional?

# %% [markdown]
# ## Tahap 4: Global Dominance & Team Performance Analysis
#
# Siapakah tim paling mematikan dalam sejarah? Kita akan menghitung statistik kumulatif untuk menemukan negara dengan performa paling konsisten.

# %%
# Out:
# /tmp/ipykernel_836/850211701.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=total_wins.values, y=total_wins.index, ax=ax[0], palette='magma')
# /tmp/ipykernel_836/850211701.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=total_goals_scored.values, y=total_goals_scored.index, ax=ax[1], palette='rocket')

# %% [markdown]
# ## Tahap 5: Tournament Segmentation
#
# Apakah laga persahabatan masih mendominasi, ataukah turnamen resmi telah mengambil alih panggung internasional?

# %%
# Out:
# /tmp/ipykernel_836/3961088068.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_tournaments.values, y=top_tournaments.index, palette='coolwarm')

# %% [markdown]
# ## 📊 Deep Dive: Categorical Data Distribution
#
# Analisis ini akan mengekstrak setiap kolom kategori, menghitung frekuensinya, dan menyajikannya dalam bentuk tabel serta visualisasi profesional (Bar & Pie Charts).

# %%
# Out:
# --- ANALISIS KOLOM: HOME_TEAM ---
#             home_team  Kuantitas  Persentase (%)
# 0              Brazil        612            1.24
# 1           Argentina        601            1.22
# 2              Mexico        599            1.22
# 3             Germany        553            1.12
# 4         South Korea        549            1.12
# ..                ...        ...             ...
# 195           Réunion         67            0.14
# 196           Comoros         66            0.13
# 197          Zanzibar         62            0.13
# 198  Vietnam Republic         60            0.12
# 199            Kosovo         59            0.12
#
# [200 rows x 3 columns]
# --- ANALISIS KOLOM: AWAY_TEAM ---
#                   away_team  Kuantitas  Persentase (%)
# 0                   Uruguay        583            1.18
# 1                    Sweden        566            1.15
# 2                   England        540            1.10
# 3                   Hungary        507            1.03
# ...
