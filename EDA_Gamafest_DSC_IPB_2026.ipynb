# %% [markdown]
# <a href="https://colab.research.google.com/github/LatiefDataVisionary/gamafest-dsc-ipb-2026/blob/main/EDA_Gamafest_DSC_IPB_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
test_df = pd.read_csv("https://raw.githubusercontent.com/LatiefDataVisionary/gamafest-dsc-ipb-2026/refs/heads/main/dataset/test.csv")
train_df = pd.read_csv("https://raw.githubusercontent.com/LatiefDataVisionary/gamafest-dsc-ipb-2026/refs/heads/main/dataset/train.csv")

# %%
train_df.head(10)
# Out:
#                  Id match_id        date gender      team  opponent  is_home  \
# 0  M000001_Scotland  M000001  1872-11-30      M  Scotland   England        1
# 1   M000001_England  M000001  1872-11-30      M   England  Scotland        0
# 2   M000002_England  M000002  1873-03-08      M   England  Scotland        1
# 3  M000002_Scotland  M000002  1873-03-08      M  Scotland   England        0
# 4  M000003_Scotland  M000003  1874-03-07      M  Scotland   England        1
# 5   M000003_England  M000003  1874-03-07      M   England  Scotland        0
# 6   M000004_England  M000004  1875-03-06      M   England  Scotland        1
# 7  M000004_Scotland  M000004  1875-03-06      M  Scotland   England        0
# 8  M000005_Scotland  M000005  1876-03-04      M  Scotland   England        1
# 9   M000005_England  M000005  1876-03-04      M   England  Scotland        0
#
#    neutral tournament venue_country  ...  confederation_team  \
# ...

# %%
test_df.head(10)
# Out:
#                     Id match_id        date gender         team     opponent  \
# 0   M034984_Seychelles  M034984  2011-08-06      M   Seychelles    Mauritius
# 1    M034984_Mauritius  M034984  2011-08-06      M    Mauritius   Seychelles
# 2      M034985_Comoros  M034985  2011-08-06      M      Comoros     Maldives
# 3     M034985_Maldives  M034985  2011-08-06      M     Maldives      Comoros
# 4      M034986_Réunion  M034986  2011-08-06      M      Réunion   Madagascar
# 5   M034986_Madagascar  M034986  2011-08-06      M   Madagascar      Réunion
# 6  M034987_El Salvador  M034987  2011-08-07      M  El Salvador    Venezuela
# 7    M034987_Venezuela  M034987  2011-08-07      M    Venezuela  El Salvador
# 8      M034988_Mayotte  M034988  2011-08-08      M      Mayotte      Réunion
# 9      M034988_Réunion  M034988  2011-08-08      M      Réunion      Mayotte
#
#    is_home  neutral                 tournament  venue_country  \
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78772 entries, 0 to 78771
# Data columns (total 47 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Id                          78772 non-null  object
#  1   match_id                    78772 non-null  object
#  2   date                        78772 non-null  object
#  3   gender                      78772 non-null  object
#  4   team                        78772 non-null  object
#  5   opponent                    78772 non-null  object
#  6   is_home                     78772 non-null  int64
#  7   neutral                     78772 non-null  int64
#  8   tournament                  78772 non-null  object
#  9   venue_country               78772 non-null  object
#  10  team_goals                  78772 non-null  int64
#  11  opp_goals                   78772 non-null  int64
#  12  team_points_last5           78478 non-null  float64
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42422 entries, 0 to 42421
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    42422 non-null  object
#  1   match_id              42422 non-null  object
#  2   date                  42422 non-null  object
#  3   gender                42422 non-null  object
#  4   team                  42422 non-null  object
#  5   opponent              42422 non-null  object
#  6   is_home               42422 non-null  int64
#  7   neutral               42422 non-null  int64
#  8   tournament            42422 non-null  object
#  9   venue_country         42422 non-null  object
#  10  confederation_team    42422 non-null  object
#  11  confederation_opp     42422 non-null  object
#  12  population_team       39050 non-null  float64
#  13  population_opp        39050 non-null  float64
#  14  gdp_per_capita_team   27758 non-null  float64
# ...

# %%
train_df.describe(include='all')
# Out:
#                        Id match_id        date gender    team opponent  \
# count               78772    78772       78772  78772   78772    78772
# unique              78772    39386       14881      2     294      294
# top     M034983_Mauritius  M034983  2008-03-26      M  Sweden   Sweden
# freq                    1        2         128  69966    1207     1207
# mean                  NaN      NaN         NaN    NaN     NaN      NaN
# std                   NaN      NaN         NaN    NaN     NaN      NaN
# min                   NaN      NaN         NaN    NaN     NaN      NaN
# 25%                   NaN      NaN         NaN    NaN     NaN      NaN
# 50%                   NaN      NaN         NaN    NaN     NaN      NaN
# 75%                   NaN      NaN         NaN    NaN     NaN      NaN
# max                   NaN      NaN         NaN    NaN     NaN      NaN
#
#              is_home       neutral tournament  venue_country  ...  \
# ...

# %%
test_df.describe(include='all')
# Out:
#                      Id match_id        date gender           team  \
# count             42422    42422       42422  42422          42422
# unique            42422    21211        3135      2            315
# top     M049215_Comoros  M049215  2012-02-29      M  United States
# freq                  1        2         144  28464            522
# mean                NaN      NaN         NaN    NaN            NaN
# std                 NaN      NaN         NaN    NaN            NaN
# min                 NaN      NaN         NaN    NaN            NaN
# 25%                 NaN      NaN         NaN    NaN            NaN
# 50%                 NaN      NaN         NaN    NaN            NaN
# 75%                 NaN      NaN         NaN    NaN            NaN
# max                 NaN      NaN         NaN    NaN            NaN
#
#              opponent       is_home       neutral tournament  venue_country  \
# count           42422  42422.000000  42422.000000      42422          42422
# ...

# %%
train_df.isnull().sum()
# Out:
# Id                                0
# match_id                          0
# date                              0
# gender                            0
# team                              0
# opponent                          0
# is_home                           0
# neutral                           0
# tournament                        0
# venue_country                     0
# team_goals                        0
# opp_goals                         0
# team_points_last5               294
# opp_points_last5                176
# points_last5_diff               440
# team_gd_last5                   294
# opp_gd_last5                    176
# gd_last5_diff                   440
# h2h_points_last5              11976
# h2h_gd_last5                  11976
# days_since_last_match_team      294
# days_since_last_match_opp       176
# team_points_last10              294
# opp_points_last10               176
# team_avg_goals_last5            294
# team_avg_conceded_last5         294
# ...

# %%
test_df.isnull().sum()
# Out:
# Id                          0
# match_id                    0
# date                        0
# gender                      0
# team                        0
# opponent                    0
# is_home                     0
# neutral                     0
# tournament                  0
# venue_country               0
# confederation_team          0
# confederation_opp           0
# population_team          3372
# population_opp           3372
# gdp_per_capita_team     14664
# gdp_per_capita_opp      14664
# altitude_venue          10906
# distance_travel_team    16975
# distance_travel_opp     16975
# temperature_venue        5594
# dtype: int64

# %%
train_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
test_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
train_df.corr(numeric_only=True)
# Out:
#                                  is_home       neutral  team_goals  opp_goals  \
# is_home                     1.000000e+00  6.020310e-16    0.181683  -0.181683
# neutral                     6.020310e-16  1.000000e+00    0.032114   0.032114
# team_goals                  1.816825e-01  3.211359e-02    1.000000  -0.194728
# opp_goals                  -1.816825e-01  3.211359e-02   -0.194728   1.000000
# team_points_last5           1.740846e-02  1.545393e-03    0.131803  -0.201483
# opp_points_last5           -6.153638e-02 -8.271397e-03   -0.286238   0.247611
# points_last5_diff           5.724216e-02  7.185295e-03    0.300410  -0.323225
# team_gd_last5               2.322921e-02 -1.508766e-02    0.158336  -0.253808
# opp_gd_last5               -6.177227e-02 -2.108723e-02   -0.344786   0.309233
# gd_last5_diff               6.069066e-02  4.477432e-03    0.361488  -0.403657
# h2h_points_last5            1.761496e-02 -2.939057e-03    0.229930  -0.255581
# ...

# %%
test_df.corr(numeric_only=True)
# Out:
#                            is_home       neutral  population_team  \
# is_home               1.000000e+00  1.416263e-16         0.041117
# neutral               1.416263e-16  1.000000e+00         0.018464
# population_team       4.111694e-02  1.846433e-02         1.000000
# population_opp       -4.111694e-02  1.846433e-02         0.029200
# gdp_per_capita_team   2.875744e-02 -7.985876e-02        -0.040112
# gdp_per_capita_opp   -2.875744e-02 -7.985876e-02        -0.031866
# altitude_venue       -1.961903e-16  7.898559e-03         0.012611
# distance_travel_team -3.992605e-01  3.710754e-01         0.025249
# distance_travel_opp   3.992605e-01  3.710754e-01         0.103394
# temperature_venue     1.018127e-16  6.149681e-02         0.015497
#
#                       population_opp  gdp_per_capita_team  gdp_per_capita_opp  \
# is_home                    -0.041117             0.028757           -0.028757
# neutral                     0.018464            -0.079859           -0.079859
# ...

# %%
train_df.corr(numeric_only=True).style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_270e5_row0_col0, #T_270e5_row1_col1, #T_270e5_row2_col2, #T_270e5_row3_col3, #T_270e5_row4_col4, #T_270e5_row5_col5, #T_270e5_row6_col6, #T_270e5_row7_col7, #T_270e5_row8_col8, #T_270e5_row9_col9, #T_270e5_row10_col10, #T_270e5_row11_col11, #T_270e5_row12_col12, #T_270e5_row13_col13, #T_270e5_row14_col14, #T_270e5_row15_col15, #T_270e5_row16_col16, #T_270e5_row17_col17, #T_270e5_row18_col18, #T_270e5_row19_col19, #T_270e5_row20_col20, #T_270e5_row21_col21, #T_270e5_row22_col22, #T_270e5_row23_col23, #T_270e5_row24_col24, #T_270e5_row25_col25, #T_270e5_row26_col26, #T_270e5_row27_col27, #T_270e5_row28_col28, #T_270e5_row29_col29, #T_270e5_row30_col30, #T_270e5_row31_col31, #T_270e5_row32_col32, #T_270e5_row33_col33, #T_270e5_row34_col34, #T_270e5_row35_col35, #T_270e5_row36_col36 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# ...
